# %%
#Convert the list into numpy array
list=[1,2,4,5,6,7]
numpy_array=np.array(list)
print(numpy_array)

#Print maximum and minimum temperature and calculate avg temp and display last 3days temp
temperature=np.array([43,65,75,67,78])
print("Maximum temperature: ",np.max(temperature))
print("Minimum temperature: ",np.min(temperature))
print("Average temperature: ",np.mean(temperature))
print("Last 3 days temperature: ",temperature[-3:])
# Out:
# [1 2 4 5 6 7]
# Maximum temperature:  78
# Minimum temperature:  43
# Average temperature:  65.6
# Last 3 days temperature:  [75 67 78]
