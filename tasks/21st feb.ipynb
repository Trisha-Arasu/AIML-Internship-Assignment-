# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Create dataset
data = {
    "Hours_Studied": [1, 2, 3, 4, 5, 6, 7, 8],
    "Sleep_Hours": [8, 7, 7, 6, 6, 5, 5, 4],
    "Previous_Score": [40, 50, 55, 60, 65, 70, 75, 80],
    "Final_Score": [42, 52, 58, 63, 68, 72, 78, 85]
}

df = pd.DataFrame(data)

# Identify feature & label
X = df[["Hours_Studied", "Sleep_Hours", "Previous_Score"]]  # Features
y = df["Final_Score"]  # Label

# Split (70-30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Train Linear Regression
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("R2 Score:", r2)
# Out:
# MAE: 1.047619047619051
# MSE: 1.3333333333333413
# R2 Score: 0.9657142857142855
