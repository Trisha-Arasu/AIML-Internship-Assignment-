# %%
"""
Assignment: Spam Classifier Thinking

1.Features (used by ML model):
   Presence of spam words (e.g., “free”, “win”, “offer”)
   Number of links in message
   Use of capital letters
   Message length
   Sender email address

2.Data Needed:
   Collection of emails/messages
   Each message labeled as spam or not spam
   Text content of messages
   Sender details and metadata

3.Possible Mistakes:
   False Positive: Normal message marked as spam
   False Negative: Spam message marked as normal
   Misclassification due to new or unseen spam words
   Errors due to incomplete or noisy data
"""
