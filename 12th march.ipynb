# %%
"""
Assignment: Decision Tree on Paper

**Conditions Used**
Weather (Sunny / Rainy)
Temperature (Hot / Cool)
Humidity (High / Normal)

**Decision Tree (Draw like this)**

                Weather
               /       \
           Sunny       Rainy
           /               \
     Humidity            Temperature
     /      \           /           \
  High     Normal     Hot          Cool
   |         |         |            |
  No        Yes       No           Yes

**Explanation**
* If weather is **Sunny**:
If humidity is **High** → Do not play
If humidity is **Normal** → Play

* If weather is **Rainy**:
If temperature is **Hot** → Do not play
If temperature is **Cool** → Play


**Input → Output**
Input: Weather conditions (weather, humidity, temperature)
Output: Decision (Play / Not Play)
"""
