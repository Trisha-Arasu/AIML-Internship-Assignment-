# %%
"""
KNN in Real Life

KNN (K-Nearest Neighbors) is a machine learning algorithm that finds the most similar data points based on distance.
It works on the idea that similar users have similar preferences.

Netflix-like Recommendation using KNN:
In platforms like Netflix, KNN is used to recommend movies by comparing users.
If two users have similar watching patterns, then movies liked by one user are recommended to the other.
The system finds the nearest (most similar) users and suggests their favorite movies.

Example (User Similarity Table)
User	Action	Comedy
A	    5	    1
B	    4	    2
C	    1	    5
User A likes Action movies more
User B also likes Action (similar to A)
User C likes Comedy (different from A)

So, User A is closest to User B
Movies liked by B will be recommended to A

KNN calculates distance between users (like Euclidean distance).
Smaller distance means more similarity.
Users with minimum distance are called nearest neighbors.

Steps of KNN in Recommendation:
Take user data (ratings)
Calculate distance between users
Find K nearest users (similar users)
Recommend items liked by those users
Input → Output
Input: User ratings or preferences
Output: Recommended movies or shows

KNN recommends items by finding similar users and suggesting their preferences.
"""
