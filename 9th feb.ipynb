# %%
# Assignment: AI Around Me

ai_applications = {
    "1. YouTube Recommendations": "ML studies your watch history, likes, and search patterns to suggest videos you may enjoy.",
    "2. Google Maps Navigation": "ML analyzes traffic data, road conditions, and user movement to predict the fastest route.",
    "3. Voice Assistants (Siri, Alexa, Google Assistant)": "ML uses speech recognition and natural language processing to understand your voice and reply.",
    "4. Email Spam Filter": "ML identifies spam by learning patterns from unwanted emails such as keywords, links, and sender behavior.",
    "5. Netflix Recommendations": "ML compares your viewing habits with others to recommend movies and shows you may like.",
    "6. Face Unlock on Phones": "ML recognizes facial features and compares them with stored data to unlock the device securely.",
    "7. Shopping Apps (Amazon, Flipkart)": "ML tracks browsing and purchase history to suggest products you are more likely to buy.",
    "8. Social Media Feed (Instagram, Facebook)": "ML ranks posts based on your interests, likes, comments, and time spent on content.",
    "9. Google Search Autocomplete": "ML predicts what you are typing by learning from common searches and user behavior.",
    "10. Banking Fraud Detection": "ML detects unusual spending patterns and flags suspicious transactions in real time."
}

print("AI Around Me - 10 Real-Life AI Applications\n")

for app, explanation in ai_applications.items():
    print(app)
    print("Explanation:", explanation)
    print()
# Out:
# AI Around Me - 10 Real-Life AI Applications
#
# 1. YouTube Recommendations
# Explanation: ML studies your watch history, likes, and search patterns to suggest videos you may enjoy.
#
# 2. Google Maps Navigation
# Explanation: ML analyzes traffic data, road conditions, and user movement to predict the fastest route.
#
# 3. Voice Assistants (Siri, Alexa, Google Assistant)
# Explanation: ML uses speech recognition and natural language processing to understand your voice and reply.
#
# 4. Email Spam Filter
# Explanation: ML identifies spam by learning patterns from unwanted emails such as keywords, links, and sender behavior.
#
# 5. Netflix Recommendations
# Explanation: ML compares your viewing habits with others to recommend movies and shows you may like.
#
# 6. Face Unlock on Phones
# Explanation: ML recognizes facial features and compares them with stored data to unlock the device securely.
#
# 7. Shopping Apps (Amazon, Flipkart)
# ...
