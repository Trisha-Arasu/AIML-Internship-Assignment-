# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Sample mall dataset
data = {
    "Income": [15, 16, 17, 18, 60, 62, 64, 65],
    "Spending": [39, 40, 42, 43, 80, 82, 85, 88]
}
df = pd.DataFrame(data)

# Apply K-Means
kmeans = KMeans(n_clusters=2)
df["Cluster"] = kmeans.fit_predict(df)
print(df)

# Plot graph
plt.scatter(df["Income"], df["Spending"], c=df["Cluster"])
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation")
plt.show()
# Out:
# c:\users\monis\jupyterenv\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#    Income  Spending  Cluster
# 0      15        39        1
# 1      16        40        1
# 2      17        42        1
# 3      18        43        1
# 4      60        80        0
# 5      62        82        0
# 6      64        85        0
# 7      65        88        0
