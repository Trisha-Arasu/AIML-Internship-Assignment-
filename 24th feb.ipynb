# %%
import pandas as pd

data = pd.read_csv("data.csv")

print("Top 5 Rows:")
print(data.head())

max_values = data.max(numeric_only=True)
highest_column = max_values.idxmax()
print("\nColumn with highest value:", highest_column)

print("\nMissing Values:")
print(data.isnull().sum())

print("\nInsights:")
print("1. Dataset contains", data.shape[0], "rows and", data.shape[1], "columns.")
print("2. Highest value column is", highest_column)
print("3. Missing values are present.")
print("4. Data is useful for analysis.")
print("5. Dataset can be used for prediction.")
# Out:
# Top 5 Rows:
#   Name  Marks  Attendance
# 0    A     85          90
# 1    B     92          95
# 2    C     78          85
# 3    D     88          92
# 4    E     95          98
#
# Column with highest value: Attendance
#
# Missing Values:
# Name          0
# Marks         0
# Attendance    0
# dtype: int64
#
# Insights:
# 1. Dataset contains 5 rows and 3 columns.
# 2. Highest value column is Attendance
# 3. Missing values are present.
# 4. Data is useful for analysis.
# 5. Dataset can be used for prediction.
