# %%
"""
College
1.Input: Study hours, attendance, previous marks
  Output: Predicted marks/grade
  Description: ML analyzes past performance to predict student results.
2.Input: Skills, CGPA, projects
  Output: Placement chances
  Description: ML evaluates student profile to estimate job placement probability.
3.Input: Interests, past performance
  Output: Course recommendation
  Description: ML suggests suitable courses based on student preferences and performance.

Healthcare
1.Input: Symptoms, age, medical history
  Output: Disease prediction
  Description: ML predicts possible diseases using patient data.
2.Input: Blood pressure, cholesterol, lifestyle
  Output: Heart risk level
  Description: ML analyzes health factors to detect risk of heart disease.
3.Input: Prescription, schedule
  Output: Medicine reminders
  Description: ML learns timing patterns to remind patients to take medicines.

Shopping
1.Input: User search history, purchases
  Output: Product recommendations
  Description: ML suggests products based on user behavior.
2.Input: Past prices, demand, season
  Output: Future price prediction
  Description: ML predicts price changes using historical data.
3.Input: Customer reviews (text)
  Output: Sentiment (positive/negative)
  Description: ML analyzes reviews to understand customer opinions.
4.Input: User browsing behavior
  Output: Personalized advertisements
  Description: ML shows ads based on user interests and activity.
"""
